# %%
def sum(a,b):
    c=a+b
    print(c)

sum(3,4)
# Out:
# 7

# %%
list = [2,6,4,"ghi"] 
for i in list: 
    if type(i) == int: 
        print(i)
# Out:
# 2
# 6
# 4

# %%
a = {1:'a', 2:'b', 3:'j', 4:'g'}

a[4] = 'k'
for keys,values in a.items():
    print(keys,values)
# Out:
# 1 a
# 2 b
# 3 j
# 4 k

# %%
dict ={'a': 100, 'b': 200, 22:100}

def summer(dict):
    num = 0
    for k,v in dict.items():
        num += v
    return num

print(summer(dict))
# Out:
# 400

# %%
a=[1,2,3,4,5,2,3,4,7,9,5]
b=[]
for i in a:
    if i not in b:
        b.append(i)
    else:
        print(i)
# Out:
# 2
# 3
# 4
# 5

# %%
a = {1:'a', 2:'b', 3:'j', 4:'g'}
for keys,values in a.items():
    print(keys,values)
    
print(a.get(5,"donot exist"))
# Out:
# 1 a
# 2 b
# 3 j
# 4 g
# donot exist
